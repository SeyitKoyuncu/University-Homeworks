# %% [markdown]
# # CENG474-PROJECT

# %% [markdown]
# ##### This project is created by Seyit Koyuncu(201911036), Zeynep Deniz Donmez(202011012) and Nadide Solmaz(201911056)

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import Dataset

# %%
dataset = pd.read_csv('heart.csv')

df = pd.DataFrame(dataset)

df.columns

#cp = Chest Pain type chest pain 
#trtbps = resting blood pressure (in mm Hg)
#chol = cholestoral in mg/dl fetched via BMI sensor
#fbs = (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false)
#restecg = resting electrocardiographic results
#thalach = maximum heart rate achieved
#exng = exercise induced angina (1 = yes; 0 = no)
#oldpeak = Previous peak
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df.shape
# Out:
# (303, 14)

# %% [markdown]
# ### Check Datas

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
df.sample(8)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 183   58    1   2     112   230    0        0       165     0      2.5    1
# 160   56    1   1     120   240    0        1       169     0      0.0    0
# 220   63    0   0     150   407    0        0       154     0      4.0    1
# 185   44    1   0     112   290    0        0       153     0      0.0    2
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 177   64    1   2     140   335    0        1       158     0      0.0    2
# 260   66    0   0     178   228    1        1       165     1      1.0    1
# 58    34    1   3     118   182    0        0       174     0      0.0    2
#
#      caa  thall  output
# 183    1      3       0
# 160    0      2       1
# 220    3      3       0
# 185    1      2       0
# 299    0      3       0
# 177    0      2       0
# 260    2      3       0
# 58     0      2       1

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#             thall      output
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trtbps        int64
# chol          int64
# fbs           int64
# restecg       int64
# thalachh      int64
# exng          int64
# oldpeak     float64
# slp           int64
# caa           int64
# thall         int64
# output        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.nunique()
# Out:
# age          41
# sex           2
# cp            4
# trtbps       49
# chol        152
# fbs           2
# restecg       3
# thalachh     91
# exng          2
# oldpeak      40
# slp           3
# caa           5
# thall         4
# output        2
# dtype: int64

# %% [markdown]
# ### CatPlot

# %%
sns.catplot(df.iloc[:, 0:4])
sns.catplot(df.iloc[:, 4:8])
sns.catplot(df.iloc[:, 8:13])

# %% [markdown]
# ### BoxPlot

# %%
sns.catplot(df.iloc[:, 0:4],kind="box")
sns.catplot(df.iloc[:, 4:8],kind="box")
sns.catplot(df.iloc[:, 8:13],kind="box")

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(df, hue = "output", diag_kind = "kde")
plt.show()

# %% [markdown]
# ### HeatMap

# %%
corelation=df.corr()
sns.heatmap(corelation)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Categorical Feature Analysis

# %%
for item in df.columns:
    plt.figure()
    sns.countplot(x = item, data = df, hue = "output")
    plt.gcf().set_size_inches(13,13)
    plt.title(item)

# %% [markdown]
# ### Bootstrap Sampling

# %%
import numpy as np
import random

x = np.random.normal(loc= 300.0, size=1000)
print(f"True mean is = {np.mean(x)}")

sample_mean = []
for i in range(3):
  y = random.sample(x.tolist(), 4)
  avg = np.mean(y)
  sample_mean.append(avg)

print(f"With bootstraping mean is = {np.mean(sample_mean)}")
print("With these mean results we can infer our data is not have so much outlier because both meanings is near")
# Out:
# True mean is = 299.99654324198167
# With bootstraping mean is = 299.8882277208807
# With these mean results we can infer our data is not have so much outlier because both meanings is near

# %% [markdown]
# # Dependent Independet Variables

# %%
x = df.iloc[:, :-1] #dependet variables
y = df.iloc[:, -1:] #independent variables

# %% [markdown]
# # Feature Selection

# %% [markdown]
# ### Chi2

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

'''
score_func = Function taking two arrays X and y, and returning a pair of arrays (scores, pvalues) or a single array with scores. 
Default is f_classif (see below “See Also”). The default function only works with classification tasks.

k = Number of top features to select. The “all” option bypasses selection, for use in a parameter search.
'''

KBest = SelectKBest(score_func = chi2, k = 12)
fit = KBest.fit(x, y)
fit_scores = fit.scores_

features = fit.transform(x)
print(fit_scores)
# Out:
# [ 23.28662399   7.57683451  62.59809791  14.8239245   23.93639448
#    0.20293368   2.97827075 188.32047169  38.91437697  72.64425301
#    9.8040952   66.44076512   5.79185297]

# %% [markdown]
# ### Mutual Information

# %%
from sklearn.feature_selection import mutual_info_classif
KBest2 = SelectKBest(score_func = mutual_info_classif, k = 10)

fit2 = KBest2.fit(x,y)
fit_scores2 = fit2.scores_

features2 = fit2.transform(x)
print(fit_scores2)
# Out:
# [0.         0.03083217 0.12494216 0.         0.08843292 0.00159083
#  0.0026754  0.0599359  0.11569863 0.09975979 0.09414567 0.11647898
#  0.13225582]
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Clear The Age

# %%
df_v2 = df.drop('age', 1) #cleaning the age column since not distrubited equal, low correleation between output and have very low mutual information value. 
#Maybe will be added in the wrapper models.
df_v2
# Out:
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\2993448263.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_v2 = df.drop('age', 1) #cleaning the age column since not distrubited equal, low correleation between output and have very low mutual information value.
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# 0      1   3     145   233    1        0       150     0      2.3    0    0
# 1      1   2     130   250    0        1       187     0      3.5    0    0
# 2      0   1     130   204    0        0       172     0      1.4    2    0
# 3      1   1     120   236    0        1       178     0      0.8    2    0
# 4      0   0     120   354    0        1       163     1      0.6    2    0
# ..   ...  ..     ...   ...  ...      ...       ...   ...      ...  ...  ...
# 298    0   0     140   241    0        1       123     1      0.2    1    0
# 299    1   3     110   264    0        1       132     0      1.2    1    0
# 300    1   0     144   193    1        1       141     0      3.4    1    2
# 301    1   0     130   131    0        1       115     1      1.2    1    1
# 302    0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# 0        1       1
# 1        2       1
# 2        2       1
# 3        2       1
# 4        2       1
# ..     ...     ...
# 298      3       0
# 299      3       0
# 300      3       0
# 301      3       0
# 302      2       0
#
# [303 rows x 13 columns]

# %% [markdown]
# ### Binning in the Age Feature

# %%
df_binning=df
age_29_50=[]
age_50_77=[]
for item in df["age"]:
    if 50>item>=29:
        age_29_50.append(1)
    else:
        age_29_50.append(0)
    
    if 50<=item<=77:
        age_50_77.append(1)
    else:
        age_50_77.append(0)

df_binning["age_29_50"]=age_29_50
df_binning["age_50_77"]=age_50_77



df_binning["output_heart_dis"]=df_binning["output"]
df_binning=df_binning.drop("output",axis=1)
df_binning=df_binning.drop("age",axis=1)
df_binning.head()
# Out:
#    sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# 0    1   3     145   233    1        0       150     0      2.3    0    0
# 1    1   2     130   250    0        1       187     0      3.5    0    0
# 2    0   1     130   204    0        0       172     0      1.4    2    0
# 3    1   1     120   236    0        1       178     0      0.8    2    0
# 4    0   0     120   354    0        1       163     1      0.6    2    0
#
#    thall  age_29_50  age_50_77  output_heart_dis
# 0      1          0          1                 1
# 1      2          1          0                 1
# 2      2          1          0                 1
# 3      2          0          1                 1
# 4      2          0          1                 1

# %% [markdown]
# ### Data Frame Without Age

# %%
x_new = df_v2.iloc[:, :-1] #dependet variables
y_new = df_v2.iloc[:, -1:] #independent variables

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)
x_train_v2, x_test_v2, y_train_v2, y_test_v2 = train_test_split(x_new, y_new, test_size=0.25, random_state=0)


from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

#scale original data
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

#scale without age feature
x_train_sc_v2 = sc.fit_transform(x_train_v2)
x_test_sc_v2 = sc.transform(x_test_v2)


#scale with robust
from sklearn import preprocessing
scaler = preprocessing.RobustScaler()
x_train_robust = scaler.fit_transform(x_train)
x_test_robust = scaler.fit_transform(x_test)

# %% [markdown]
# ### PCA

# %%
from sklearn.decomposition import PCA
pca=PCA().fit(x_train_sc)

plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))

plt.xlabel("Num of component")
plt.ylabel("Varience")
plt.title("Explained Varience")
plt.show()

# %%
pca_data=PCA(n_components=2).fit(x_train_sc).transform(x_train_sc)
pca_data=pd.DataFrame(data=pca_data,columns=["Component 1","Component 2"])
pca_data.head()
# Out:
#    Component 1  Component 2
# 0     0.116344    -0.088855
# 1    -1.304243    -1.218933
# 2    -0.760886     0.123970
# 3     2.027582     1.516172
# 4     2.856537    -0.916085

# %%
plt.figure()
plt.xlabel("Component 1")
plt.ylabel("Component 2")
plt.title("2 component PCA")
plt.scatter(pca_data["Component 1"],pca_data["Component 2"])

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

#original data
rnd = RandomForestClassifier()
rnd.fit(x_train,y_train)

#prediction
y_preds = rnd.predict(x_test)

#score of train set
score_train=rnd.score(x_train,y_train)
print(score_train)

#score of test set
score_test=rnd.score(x_test,y_test)
print(score_test)

accuracy_rnd = accuracy_score(y_preds, y_test)
# Out:
# 1.0
# 0.868421052631579
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\1505320555.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd.fit(x_train,y_train)

# %%
conf_mat = confusion_matrix(y_test, y_preds)
print(conf_mat)

sns.heatmap(conf_mat,annot=True)
print(accuracy_score(y_test, y_preds))
print(confusion_matrix(y_test, y_preds))
# Out:
# [[27  6]
#  [ 4 39]]
# 0.868421052631579
# [[27  6]
#  [ 4 39]]

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_params = {"cosine", "euclidean", "manhattan", "nan_euclidean"}
best_accuracy_knn = 0
best_metric = ""
best_neighbor_count = 0

for i in range(1,10):
    for param in knn_params:
        knn = KNeighborsClassifier(n_neighbors=i, metric = param, weights = "distance")
        knn.fit(x_train, y_train)
        y_pred = knn.predict(x_test)
        if best_accuracy_knn < accuracy_score(y_test, y_pred):
            best_accuracy_knn, best_neighbor_count, best_metric = accuracy_score(y_test, y_pred), i, param

print(f"Best accuracy with no scaler is = {best_accuracy_knn}, with {best_neighbor_count} n_neighbors and {best_metric} metric")
knn = KNeighborsClassifier(n_neighbors=best_neighbor_count, metric = best_metric, weights = "distance")
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)
print(confusion_matrix(y_test,y_pred))
# Out:
# Best accuracy with no scaler is = 0.7105263157894737, with 6 n_neighbors and cosine metric
# [[20 13]
#  [ 9 34]]
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
print(f"Accuracy score with age  = {accuracy_score(y_test, y_preds)}")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy score with age  = 0.868421052631579
# [[20 13]
#  [ 9 34]]

# %% [markdown]
# ### SVM

# %%
from sklearn import  svm, metrics
#Import svm model
from sklearn import svm

#Create a svm Classifier (linear)
model_svm = svm.SVC(kernel='linear') 
model_svm.fit(x_train, y_train)
y_pred_lin= model_svm.predict(x_test)


#Create a svm Classifier (poly)
model_svm_pol = svm.SVC(kernel='poly', degree=10)
model_svm_pol.fit(x_train, y_train)
y_pred_pol = model_svm_pol.predict(x_test)



print("Accuracy linear:",metrics.accuracy_score(y_test, y_pred_lin))
accuracy_svm_lin=metrics.accuracy_score(y_test, y_pred_lin)
print(confusion_matrix(y_test,y_pred_lin))
print("Accuracy polynomial:",metrics.accuracy_score(y_test, y_pred_pol))
accuracy_svm_pol=metrics.accuracy_score(y_test, y_pred_pol)
print(confusion_matrix(y_test,y_pred_pol))
# Out:
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy linear: 0.8421052631578947
# [[24  9]
#  [ 3 40]]
# Accuracy polynomial: 0.7236842105263158
# [[25  8]
#  [13 30]]
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### LogReg

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()
log_reg.fit(x_train, y_train)
y_pred= log_reg.predict(x_test)
accuracy_logreg = accuracy_score(y_test, y_pred)
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.8421052631578947
# [[24  9]
#  [ 3 40]]
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

naive_bayes = GaussianNB()
naive_bayes.fit(x_train, y_train)
y_pred = naive_bayes.predict(x_test)
print(accuracy_score(y_test, y_pred))
accuracy_naive=accuracy_score(y_test, y_pred)
print(confusion_matrix(y_test,y_pred))
# Out:
# 0.8289473684210527
# [[24  9]
#  [ 4 39]]
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### KERAS - DL

# %%
from keras.models import Sequential
model_keras=Sequential()

from keras.layers import Dense, Activation

classifier_keras = Sequential()
classifier_keras.add(Dense(16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 13))
classifier_keras.add(Dense(8, kernel_initializer = 'uniform', activation = 'relu'))
classifier_keras.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

classifier_keras.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

classifier_keras.fit(x_test_sc, y_test, epochs=150, batch_size=10)

y_pred_keras = model_keras.predict(x_test) 
y_pred_keras = np.array(y_pred_keras)
y_pred_keras = (y_pred_keras > 0.5)
# Out:
# Epoch 1/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6930 - accuracy: 0.5526
# Epoch 2/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6924 - accuracy: 0.5658
# Epoch 3/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6917 - accuracy: 0.5658
# Epoch 4/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6906 - accuracy: 0.5658
# Epoch 5/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.6885 - accuracy: 0.5658
# Epoch 6/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6855 - accuracy: 0.5658
# Epoch 7/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6803 - accuracy: 0.5789
# Epoch 8/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.6733 - accuracy: 0.6184
# Epoch 9/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.6621 - accuracy: 0.7632
# Epoch 10/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.6487 - accuracy: 0.7895
# Epoch 11/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6316 - accuracy: 0.8158
# Epoch 12/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.6106 - accuracy: 0.8421
# Epoch 13/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.5863 - accuracy: 0.8289
# Epoch 14/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.5625 - accuracy: 0.8289
# Epoch 15/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.5335 - accuracy: 0.8421
# Epoch 16/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.5078 - accuracy: 0.8553
# Epoch 17/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.4827 - accuracy: 0.8553
# Epoch 18/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.4616 - accuracy: 0.8421
# Epoch 19/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.4417 - accuracy: 0.8421
# Epoch 20/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.4216 - accuracy: 0.8421
# Epoch 21/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.4034 - accuracy: 0.8553
# Epoch 22/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.3873 - accuracy: 0.8553
# Epoch 23/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.3705 - accuracy: 0.8684
# Epoch 24/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.3554 - accuracy: 0.8816
# Epoch 25/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.3416 - accuracy: 0.8816
# Epoch 26/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.3275 - accuracy: 0.8816
# Epoch 27/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.3161 - accuracy: 0.8816
# Epoch 28/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.3065 - accuracy: 0.8947
# Epoch 29/150
# 8/8 [==============================] - 0s 715us/step - loss: 0.2972 - accuracy: 0.9079
# Epoch 30/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2870 - accuracy: 0.9079
# Epoch 31/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.2799 - accuracy: 0.9079
# Epoch 32/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2722 - accuracy: 0.9079
# Epoch 33/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2660 - accuracy: 0.9211
# Epoch 34/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2605 - accuracy: 0.9211
# Epoch 35/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2548 - accuracy: 0.9211
# Epoch 36/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2496 - accuracy: 0.9211
# Epoch 37/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2458 - accuracy: 0.9211
# Epoch 38/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.2413 - accuracy: 0.9211
# Epoch 39/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2368 - accuracy: 0.9211
# Epoch 40/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2337 - accuracy: 0.9211
# Epoch 41/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2301 - accuracy: 0.9211
# Epoch 42/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2271 - accuracy: 0.9211
# Epoch 43/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2240 - accuracy: 0.9211
# Epoch 44/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2212 - accuracy: 0.9211
# Epoch 45/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2188 - accuracy: 0.9211
# Epoch 46/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.2162 - accuracy: 0.9211
# Epoch 47/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2129 - accuracy: 0.9211
# Epoch 48/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.2109 - accuracy: 0.9211
# Epoch 49/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2081 - accuracy: 0.9211
# Epoch 50/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2058 - accuracy: 0.9211
# Epoch 51/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2030 - accuracy: 0.9211
# Epoch 52/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.2010 - accuracy: 0.9211
# Epoch 53/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1983 - accuracy: 0.9211
# Epoch 54/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1963 - accuracy: 0.9211
# Epoch 55/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1940 - accuracy: 0.9211
# Epoch 56/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1915 - accuracy: 0.9211
# Epoch 57/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1893 - accuracy: 0.9211
# Epoch 58/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1870 - accuracy: 0.9211
# Epoch 59/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1847 - accuracy: 0.9211
# Epoch 60/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1823 - accuracy: 0.9211
# Epoch 61/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1802 - accuracy: 0.9211
# Epoch 62/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1781 - accuracy: 0.9211
# Epoch 63/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1754 - accuracy: 0.9211
# Epoch 64/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1732 - accuracy: 0.9211
# Epoch 65/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1713 - accuracy: 0.9211
# Epoch 66/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1686 - accuracy: 0.9211
# Epoch 67/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1665 - accuracy: 0.9211
# Epoch 68/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1642 - accuracy: 0.9211
# Epoch 69/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1624 - accuracy: 0.9211
# Epoch 70/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.1602 - accuracy: 0.9342
# Epoch 71/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.1583 - accuracy: 0.9342
# Epoch 72/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1564 - accuracy: 0.9342
# Epoch 73/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1543 - accuracy: 0.9342
# Epoch 74/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1528 - accuracy: 0.9342
# Epoch 75/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1507 - accuracy: 0.9342
# Epoch 76/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1489 - accuracy: 0.9342
# Epoch 77/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1475 - accuracy: 0.9342
# Epoch 78/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1451 - accuracy: 0.9342
# Epoch 79/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1435 - accuracy: 0.9342
# Epoch 80/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1415 - accuracy: 0.9342
# Epoch 81/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1398 - accuracy: 0.9342
# Epoch 82/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1384 - accuracy: 0.9474
# Epoch 83/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1367 - accuracy: 0.9474
# Epoch 84/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1353 - accuracy: 0.9474
# Epoch 85/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1334 - accuracy: 0.9474
# Epoch 86/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1322 - accuracy: 0.9474
# Epoch 87/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1307 - accuracy: 0.9474
# Epoch 88/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1295 - accuracy: 0.9474
# Epoch 89/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1281 - accuracy: 0.9474
# Epoch 90/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1266 - accuracy: 0.9474
# Epoch 91/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1253 - accuracy: 0.9474
# Epoch 92/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1238 - accuracy: 0.9474
# Epoch 93/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1226 - accuracy: 0.9474
# Epoch 94/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1213 - accuracy: 0.9474
# Epoch 95/150
# 8/8 [==============================] - 0s 858us/step - loss: 0.1200 - accuracy: 0.9474
# Epoch 96/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1187 - accuracy: 0.9474
# Epoch 97/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1173 - accuracy: 0.9474
# Epoch 98/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1163 - accuracy: 0.9474
# Epoch 99/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1148 - accuracy: 0.9605
# Epoch 100/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1136 - accuracy: 0.9605
# Epoch 101/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1125 - accuracy: 0.9605
# Epoch 102/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1112 - accuracy: 0.9605
# Epoch 103/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1104 - accuracy: 0.9605
# Epoch 104/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1091 - accuracy: 0.9605
# Epoch 105/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1080 - accuracy: 0.9605
# Epoch 106/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1070 - accuracy: 0.9605
# Epoch 107/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1059 - accuracy: 0.9605
# Epoch 108/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1048 - accuracy: 0.9605
# Epoch 109/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1037 - accuracy: 0.9605
# Epoch 110/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.1031 - accuracy: 0.9605
# Epoch 111/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.1019 - accuracy: 0.9605
# Epoch 112/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1010 - accuracy: 0.9605
# Epoch 113/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.1004 - accuracy: 0.9605
# Epoch 114/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0996 - accuracy: 0.9605
# Epoch 115/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0980 - accuracy: 0.9605
# Epoch 116/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0965 - accuracy: 0.9605
# Epoch 117/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0955 - accuracy: 0.9605
# Epoch 118/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0938 - accuracy: 0.9605
# Epoch 119/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0928 - accuracy: 0.9737
# Epoch 120/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0915 - accuracy: 0.9737
# Epoch 121/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0903 - accuracy: 0.9737
# Epoch 122/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0889 - accuracy: 0.9737
# Epoch 123/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0878 - accuracy: 0.9868
# Epoch 124/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0866 - accuracy: 0.9868
# Epoch 125/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0853 - accuracy: 0.9868
# Epoch 126/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0844 - accuracy: 0.9868
# Epoch 127/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0835 - accuracy: 0.9868
# Epoch 128/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0826 - accuracy: 0.9868
# Epoch 129/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0814 - accuracy: 0.9868
# Epoch 130/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0804 - accuracy: 0.9868
# Epoch 131/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0799 - accuracy: 0.9868
# Epoch 132/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0787 - accuracy: 0.9868
# Epoch 133/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0779 - accuracy: 0.9868
# Epoch 134/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0772 - accuracy: 0.9868
# Epoch 135/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0764 - accuracy: 0.9868
# Epoch 136/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0754 - accuracy: 0.9868
# Epoch 137/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0747 - accuracy: 0.9868
# Epoch 138/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0742 - accuracy: 0.9868
# Epoch 139/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0731 - accuracy: 0.9868
# Epoch 140/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0727 - accuracy: 0.9868
# Epoch 141/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0719 - accuracy: 0.9868
# Epoch 142/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0711 - accuracy: 0.9868
# Epoch 143/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0703 - accuracy: 0.9868
# Epoch 144/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0697 - accuracy: 0.9868
# Epoch 145/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0691 - accuracy: 0.9868
# Epoch 146/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0683 - accuracy: 0.9868
# Epoch 147/150
# 8/8 [==============================] - 0s 714us/step - loss: 0.0675 - accuracy: 0.9868
# Epoch 148/150
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9868
# Epoch 149/150
# 8/8 [==============================] - 0s 857us/step - loss: 0.0660 - accuracy: 0.9868
# Epoch 150/150
# 8/8 [==============================] - 0s 1000us/step - loss: 0.0653 - accuracy: 0.9868
# 3/3 [==============================] - 0s 1ms/step

# %%
accuracy_keras = classifier_keras.evaluate(x_train_sc, y_train)
print(f"Accuracy:{accuracy_keras}")

y_pred = classifier_keras.predict(x_test_sc) 
y_pred = np.array(y_pred)
y_pred = (y_pred > 0.5)

print(f"Accuracy score with keras = {accuracy_score(y_test, y_pred)}")
accuracy_keras=accuracy_score(y_test, y_pred)
print(confusion_matrix(y_test, y_pred))
# Out:
# 8/8 [==============================] - 0s 857us/step - loss: 1.0159 - accuracy: 0.7974
# Accuracy:[1.0159345865249634, 0.7973568439483643]
# 3/3 [==============================] - 0s 1ms/step
# Accuracy score with keras = 0.9868421052631579
# [[33  0]
#  [ 1 42]]

# %% [markdown]
# ### Print All Accuracys

# %%
set_accuracys = [   ('Random Forest', accuracy_rnd),
                    ('KNN', best_accuracy_knn),
                    ('SVM Linear', accuracy_svm_lin),
                    ('SVM Polynomial', accuracy_svm_pol),
                    ('Naive Bayes', accuracy_naive),
                    ('Keras', accuracy_keras),
                    ('Logistic Regression', accuracy_logreg)]

for (model, accuracy) in set_accuracys:
    print(f"Accuracy = {accuracy} for {model}")
# Out:
# Accuracy = 0.868421052631579 for Random Forest
# Accuracy = 0.7105263157894737 for KNN
# Accuracy = 0.8421052631578947 for SVM Linear
# Accuracy = 0.7236842105263158 for SVM Polynomial
# Accuracy = 0.8289473684210527 for Naive Bayes
# Accuracy = 0.9868421052631579 for Keras
# Accuracy = 0.8421052631578947 for Logistic Regression

# %% [markdown]
# ### Show the accuracys

# %%
accuracy_list=[accuracy_rnd, best_accuracy_knn, accuracy_svm_lin, accuracy_svm_pol, accuracy_keras, accuracy_naive, accuracy_logreg]

target=["Random", "KNN", "SVM(L)", "SVM(P)", "Keras", "Naive", "LogReg"]
plt.plot(target,accuracy_list,"-ok", color='purple')
plt.title("Accuracy") 
plt.grid("True")
# Out:
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\2299049072.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(target,accuracy_list,"-ok", color='purple')

# %% [markdown]
# ### K Fold

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

kf = KFold(n_splits = 7)
models = {naive_bayes, rnd, model_svm, model_svm_pol, knn, log_reg}

best_x_trains = {}
best_y_trains = {}

for key in models:
    scores = cross_val_score(key, x, y, scoring='accuracy', cv=kf, n_jobs=-1)
    print(f"Score for {key} {scores}")
# Out:
# Score for SVC(kernel='linear') [0.84090909 0.86363636 0.81395349 0.81395349 0.72093023 0.8372093
#  0.58139535]
# Score for KNeighborsClassifier(metric='cosine', n_neighbors=6, weights='distance') [0.52272727 0.70454545 0.53488372 0.58139535 0.46511628 0.53488372
#  0.41860465]
# Score for SVC(degree=10, kernel='poly') [0.43181818 0.56818182 0.51162791 0.53488372 0.13953488 0.27906977
#  0.09302326]
# Score for LogisticRegression() [0.84090909 0.86363636 0.74418605 0.79069767 0.74418605 0.81395349
#  0.62790698]
# Score for RandomForestClassifier() [0.77272727 0.81818182 0.6744186  0.8372093  0.76744186 0.72093023
#  0.58139535]
# Score for GaussianNB() [0.77272727 0.88636364 0.76744186 0.81395349 0.81395349 0.8372093
#  0.62790698]

# %% [markdown]
# ### Feature Elimination for Random Forest

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

sfs = SFS(RandomForestClassifier(),k_features=6,forward=True,floating=False,scoring = 'r2',cv = 0)
sfs.fit_transform(x,y)
sfs.k_feature_names_
# Out:
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# c:\Users\AMD\AppData\Local\Programs\Python\Python310\lib\site-packages\mlxtend\feature_selection\utilities.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   selector.est_.fit(X[:, IDX], y, **fit_params)
# ('age', 'sex', 'cp', 'trtbps', 'chol', 'thalachh')

# %%
x_featureElimination = df.drop('chol',1)
x_featureElimination = df.drop('fbs',1)
x_featureElimination = df.drop('restecg',1)
x_featureElimination = df.drop('exng',1)
x_featureElimination = df.drop('oldpeak',1)
x_featureElimination = df.drop('slp',1)
x_featureElimination = df.drop('caa',1)
x_featureElimination = df.drop('thall',1)

x_train_FE, x_test_FE, y_train__FE, y_test_FE = train_test_split(x_featureElimination, y, test_size=0.25, random_state=0)
# Out:
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('chol',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('fbs',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('restecg',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('exng',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('oldpeak',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('slp',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('caa',1)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\17592690.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   x_featureElimination = df.drop('thall',1)

# %% [markdown]
# ### Roc Curve For Random Forest

# %%
from sklearn.metrics import roc_auc_score, roc_curve

y_pro=rnd.predict_proba(x_test)

y_pro_pos=y_pro[:,1]
print(y_pro_pos)

import matplotlib.pyplot as plt

def visual_roc_curve(y_test, y_pro_pos):

    fpr, tpr, thresholds = roc_curve(y_test, y_pro_pos)
    plt.plot(fpr, tpr,color="red",label="ROC")
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.plot([0,1],[0,1],color="blue")
    plt.title("ROC with age")
  

visual_roc_curve(y_test,y_pro_pos)
# Out:
# [0.15 0.55 0.68 0.01 0.1  0.48 0.27 0.04 0.06 0.1  0.57 0.93 0.11 0.98
#  0.97 0.72 0.25 0.86 0.03 0.56 0.85 0.35 0.16 0.33 0.65 0.36 0.18 0.36
#  0.92 0.75 0.59 0.17 0.98 0.8  0.99 0.49 0.16 0.93 0.1  0.42 0.68 0.53
#  0.95 0.11 0.35 0.63 0.93 0.44 0.09 0.83 0.92 0.67 0.95 0.67 0.95 0.22
#  0.86 0.8  0.8  0.98 0.82 0.99 0.67 0.86 0.68 0.71 0.71 0.17 0.69 0.85
#  0.46 0.98 0.88 0.04 0.18 0.55]

# %% [markdown]
# ### Random Forest with Scaler and with Age

# %%
#Random Forest with age and standart scaler
rnd = RandomForestClassifier()
rnd.fit(x_train_sc,y_train)
y_predict_scaler = rnd.predict(x_test_sc)
rnd_scaler_accuracy = accuracy_score(y_predict_scaler, y_test)

#Random Forest without age but standart scaler
rnd = RandomForestClassifier()
rnd.fit(x_train_sc_v2,y_train)
y_predict_scaler_v2 = rnd.predict(x_test_sc_v2)
rnd_scaler_accuracy_v2 = accuracy_score(y_predict_scaler_v2, y_test)

#Random Forest without age but robust scaler
rnd = RandomForestClassifier()
rnd.fit(x_train_robust,y_train)
y_predict_robust = rnd.predict(x_test_robust)
rnd_robust_accuracy = accuracy_score(y_predict_robust, y_test)

#Random Forest with feature elimation
rnd = RandomForestClassifier()
rnd.fit(x_train_FE,y_train)
y_predict_FE = rnd.predict(x_test_FE)
rnd_FE_accuracy= accuracy_score(y_predict_FE, y_test)
# Out:
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\791550988.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd.fit(x_train_sc,y_train)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\791550988.py:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd.fit(x_train_sc_v2,y_train)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\791550988.py:15: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd.fit(x_train_robust,y_train)
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\791550988.py:21: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rnd.fit(x_train_FE,y_train)

# %% [markdown]
# ### Hold Accuracys

# %%
random_forest_accuracys = [ ("Age/Scaler", rnd_scaler_accuracy),
                            ("Without age/Scaler", rnd_scaler_accuracy_v2),
                            ("Without age/Robust Scaler", rnd_robust_accuracy),
                            ("Age/Without Scaler",accuracy_rnd),
                            ("With feature elimation", rnd_FE_accuracy)]           
for (name, accuracy) in random_forest_accuracys:
    print(f"{name}'s accuracy = {accuracy}")
# Out:
# Age/Scaler's accuracy = 0.881578947368421
# Without age/Scaler's accuracy = 0.8157894736842105
# Without age/Robust Scaler's accuracy = 0.8289473684210527
# Age/Without Scaler's accuracy = 0.868421052631579
# With feature elimation's accuracy = 1.0

# %% [markdown]
# ### Graph For Accuracys

# %%
random_forests = ["Age/Scaler", "Without age/Scaler", "Without age/Robust Scaler",
                  "Age/Without Scaler", "With feature elimation"]
random_forests_accuracys = [rnd_scaler_accuracy, rnd_scaler_accuracy_v2, rnd_robust_accuracy,
                            accuracy_rnd, rnd_FE_accuracy] 

from matplotlib.pyplot import figure
figure(figsize=(10, 10), dpi=50)
plt.plot(random_forests,random_forests_accuracys,"-ok", color='purple')
plt.title("Accuracy") 
plt.grid("True")
# Out:
# C:\Users\AMD\AppData\Local\Temp\ipykernel_19040\2075161067.py:8: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-ok" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(random_forests,random_forests_accuracys,"-ok", color='purple')
